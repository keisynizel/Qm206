# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
class RegLin:
    def __init__(self):
        self.pendiente=0
        self.intercepto=0
        """Calcula la pendiente y el intercepto de la regresión lineal"""
    def regresion_lineal(self,x,y):
        n=len(x)
        detM=n*sum(x*x)-sum(x)*sum(x)
        detA=sum(y)*sum(x*x)-sum(x*y)*sum(x)
        detB=n*sum(x*y)-sum(x)*sum(y)
        a=detA/detM
        b=detB/detM
        self.pendiente=b
        self.intercepto=a
        return [a,b]
    def graficar(self,x,y):
        ycalc=x*self.pendiente+self.intercepto
        plt.plot(x,y,'ro')
        plt.plot(x,ycalc,'b--')
        plt.xlabel("t(seg)")
        plt.ylabel("distancia(m)")
        plt.title("Distancia vs tiempo")
        plt.show()

# %%
def regresion_lineal(x,y):
    n=len(x)
    detM=n*sum(x*x)-sum(x)*sum(x)
    detA=sum(y)*sum(x*x)-sum(x*y)*sum(x)
    detB=n*sum(x*y)-sum(x)*sum(y)
    a=detA/detM
    b=detB/detM
    return [a,b]

# %%
x=np.array([0,1,2,3,4,5])
y=x*5+2+4+np.random.randn(6)*1
reg=regresion_lineal(x,y)
ycalc=x*reg[1]+reg[0]
ycalc
# Out:
# array([  5.33950688,  10.64999392,  15.96048096,  21.27096799,
#         26.58145503,  31.89194207])

# %%
plt.plot(x,y,'ro')
plt.xlabel("t(seg)")
plt.ylabel("distancia(m)")
plt.title("Distancia vs tiempo")
plt.show()

# %%
x=np.array([0,1,2,3,4,5])
y=x*5+4+np.random.randn(6)

reg=RegLin()
reg.regresion_lineal(x,y)
reg.graficar(x,y)

# %%
reg.pendiente
# Out:
# 5.0

# %%
reg.intercepto
# Out:
# 4.0
