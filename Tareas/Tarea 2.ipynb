# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
x=np.random.randn(100)
y=np.random.randn(100)
x2=x.cumsum()
y2=y.cumsum()
plt.xlabel("xx")
plt.ylabel("yy")
plt.suptitle("xx vs yy")
plt.grid(True)
plt.plot(x2,y2)
plt.show()
