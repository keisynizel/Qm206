# %% [markdown]
# Examen Parcial No. 2
#
# RESUELVA LOS SIGUIENTES PROBLEMAS
#
# 1. Para el $CH_{4(g)}$ calcule los coeficientes de la ecuación de Shomate utilizando los datos de $C_p$ de la tabla de JANAF. https://janaf.nist.gov/tables/C-067.txt en el intervalo de temperatura 0-1200 K
# A partir de estos datos calcule los valores de $\Delta H$ y $\Delta S$ realizando las integrales correspondientes en el intervalo de temperatura 298-1200 K. Presente los gráficos correspondientes.
# Calcule $\Delta G$ en el intervalo T=298-1200 K y haga el gráfico correspondiente.

# %%
import numpy as np
import matplotlib.pyplot as plt
import pandas as pd

# %% [markdown]
# 2. Calcule la constante de equilibrio para el sistema:
#
# $NO_{(g)}+ \frac{1}{2} O_{2(g)} \rightleftharpoons NO_{2(g)}$
#
# a 298 K y p=1 bar
# Debe presentar en forma gráfica y analítica la determinación del punto de equilibrio $\xi_{eq}$

# %% [markdown]
# 3. El DNA es una secuencia de nucleótidos de las bases nitrogenadas A,G,C,T
# Diseñe una función que genere una cadena o secuencia aleatoria de 1000 bases nitrogenadas.
# A partir de esta secuencia determine el número de bases de cada clase y contruya un histograma que represente dichos datos

# %%
b_nitrogenadas=["A","G","C","T"]
for i in range(1000):
     print(b_nitrogenadas)
# Out:
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ['A', 'G', 'C', 'T']
# ...
